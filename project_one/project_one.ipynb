# %%
import cv2 as cv2
import numpy as np
from numpy import random
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import scipy.signal as signal

# %%
def import_image_as_greyscale(fp):
    image = cv2.imread(fp)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
def normalize(im, gamma, sigma):
    return gamma*(im**2 /(sigma**2 + np.sum(im**2)))

# %%
def normalize_adapt(im, gamma, sigma):
    x, y, z = im.shape
    imtmp = im.reshape((x*y, z))
    print(imtmp.shape)
    
    w = np.asarray([1, 1, 1])
    weights = imtmp.dot(w)
    print(weights.shape)
    
    ker = np.asarray([0, 0.2, 0.5, 0.75, 1, 0.75, 0.5, 0.2, 0])
    
    #sig = signal.convolve(weights, ker)

# %%
arr = np.asarray([1, 3, 5, 7, 9])

print(normalize(arr, 10, .01))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0055cd4dc2c5> in <module>
# ----> 1 arr = np.asarray([1, 3, 5, 7, 9])
#       2
#       3 print(normalize(arr, 10, .01))
#
# NameError: name 'np' is not defined

# %%
plt.plot(arr, arr)
plt.plot(arr, normalize(arr, 100, .01))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7bb9b9b7da25> in <module>
# ----> 1 plt.plot(arr, arr)
#       2 plt.plot(arr, normalize(arr, 100, .01))
#
# NameError: name 'plt' is not defined

# %%
testim = import_image_as_greyscale('data/fish.png')
plt.imshow(testim)

# %%
normalize_adapt(testim, 1, 1)

# %%
im2 = normalize(testim, 500000, .001)
plt.imshow(im2)
im2.shape
im2[0, 0, 0]
np.max(im2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 49.36252532448924

# %%
tmbw = cv2.cvtColor(testim, cv2.COLOR_BGR2GRAY)
plt.imshow(tmbw, cmap='gray')

# %%
tmb2 = normalize(tmbw, 100000, .0001)
plt.imshow(tmb2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(0, testim.shape[0] - 1, testim.shape[0])
y = np.linspace(0, testim.shape[1] - 1, testim.shape[1])

z1 = cv2.cvtColor(testim, cv2.COLOR_BGR2GRAY)

xv, yv = np.meshgrid(x, y)
ax.scatter(xv, yv, z1)

# %%
plt.imshow(z1)

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111, projection='3d')
ax2.scatter(xv, yv, tmb2)
